# %%
! pip install imutils
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: imutils in c:\users\prana\appdata\roaming\python\python311\site-packages (0.5.4)

# %%
! pip install opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting opencv-python
#   Obtaining dependency information for opencv-python from https://files.pythonhosted.org/packages/38/d2/3e8c13ffc37ca5ebc6f382b242b44acb43eb489042e1728407ac3904e72f/opencv_python-4.8.1.78-cp37-abi3-win_amd64.whl.metadata
#   Using cached opencv_python-4.8.1.78-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=1.21.2 in c:\programdata\anaconda3\lib\site-packages (from opencv-python) (1.24.3)
# Using cached opencv_python-4.8.1.78-cp37-abi3-win_amd64.whl (38.1 MB)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.8.1.78

# %%
! pip install cmake
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: cmake in c:\users\prana\appdata\roaming\python\python311\site-packages (3.27.7)

# %%
! pip install dlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting dlib
#   Using cached dlib-19.24.2.tar.gz (11.8 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Building wheels for collected packages: dlib
#   Building wheel for dlib (pyproject.toml): started
#   Building wheel for dlib (pyproject.toml): finished with status 'error'
# Failed to build dlib
#   error: subprocess-exited-with-error
#
#   × Building wheel for dlib (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [78 lines of output]
#       running bdist_wheel
#       running build
#       running build_ext
#       <string>:125: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#       Building extension for Python 3.11.5 | packaged by Anaconda, Inc. | (main, Sep 11 2023, 13:26:23) [MSC v.1916 64 bit (AMD64)]
#       Invoking CMake setup: 'cmake C:\Users\prana\AppData\Local\Temp\pip-install-sk3cw1p3\dlib_d8a741a5b1e3490e9d9384741424ebf3\tools\python -DCMAKE_LIBRARY_OUTPUT_DIRECTORY=C:\Users\prana\AppData\Local\Temp\pip-install-sk3cw1p3\dlib_d8a741a5b1e3490e9d9384741424ebf3\build\lib.win-amd64-cpython-311 -DPYTHON_EXECUTABLE=C:\ProgramData\anaconda3\python.exe -DCMAKE_LIBRARY_OUTPUT_DIRECTORY_RELEASE=C:\Users\prana\AppData\Local\Temp\pip-install-sk3cw1p3\dlib_d8a741a5b1e3490e9d9384741424ebf3\build\lib.win-amd64-cpython-311 -A x64'
#       -- Building for: NMake Makefiles
#       CMake Error at CMakeLists.txt:5 (message):
#
#
#
#         !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#
#
#         You must use Visual Studio to build a python extension on windows.  If you
#         are getting this error it means you have not installed Visual C++.  Note
#         that there are many flavors of Visual Studio, like Visual Studio for C#
#         development.  You need to install Visual Studio for C++.
#
#
#         !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#
#
#
#
#       -- Configuring incomplete, errors occurred!
#       Traceback (most recent call last):
#         File "C:\ProgramData\anaconda3\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 353, in <module>
#           main()
#         File "C:\ProgramData\anaconda3\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 335, in main
#           json_out['return_val'] = hook(**hook_input['kwargs'])
#                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "C:\ProgramData\anaconda3\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 251, in build_wheel
#           return _build_backend().build_wheel(wheel_directory, config_settings,
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "C:\Users\prana\AppData\Local\Temp\pip-build-env-8r2kn7u7\overlay\Lib\site-packages\setuptools\build_meta.py", line 434, in build_wheel
#           return self._build_with_temp_dir(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "C:\Users\prana\AppData\Local\Temp\pip-build-env-8r2kn7u7\overlay\Lib\site-packages\setuptools\build_meta.py", line 419, in _build_with_temp_dir
#           self.run_setup()
#         File "C:\Users\prana\AppData\Local\Temp\pip-build-env-8r2kn7u7\overlay\Lib\site-packages\setuptools\build_meta.py", line 341, in run_setup
#           exec(code, locals())
#         File "<string>", line 218, in <module>
#         File "C:\Users\prana\AppData\Local\Temp\pip-build-env-8r2kn7u7\overlay\Lib\site-packages\setuptools\__init__.py", line 103, in setup
#           return distutils.core.setup(**attrs)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "C:\Users\prana\AppData\Local\Temp\pip-build-env-8r2kn7u7\overlay\Lib\site-packages\setuptools\_distutils\core.py", line 185, in setup
#           return run_commands(dist)
#                  ^^^^^^^^^^^^^^^^^^
#         File "C:\Users\prana\AppData\Local\Temp\pip-build-env-8r2kn7u7\overlay\Lib\site-packages\setuptools\_distutils\core.py", line 201, in run_commands
#           dist.run_commands()
#         File "C:\Users\prana\AppData\Local\Temp\pip-build-env-8r2kn7u7\overlay\Lib\site-packages\setuptools\_distutils\dist.py", line 969, in run_commands
#           self.run_command(cmd)
#         File "C:\Users\prana\AppData\Local\Temp\pip-build-env-8r2kn7u7\overlay\Lib\site-packages\setuptools\dist.py", line 989, in run_command
#           super().run_command(command)
#         File "C:\Users\prana\AppData\Local\Temp\pip-build-env-8r2kn7u7\overlay\Lib\site-packages\setuptools\_distutils\dist.py", line 988, in run_command
#           cmd_obj.run()
#         File "C:\Users\prana\AppData\Local\Temp\pip-build-env-8r2kn7u7\overlay\Lib\site-packages\wheel\bdist_wheel.py", line 364, in run
#           self.run_command("build")
#         File "C:\Users\prana\AppData\Local\Temp\pip-build-env-8r2kn7u7\overlay\Lib\site-packages\setuptools\_distutils\cmd.py", line 318, in run_command
#           self.distribution.run_command(command)
#         File "C:\Users\prana\AppData\Local\Temp\pip-build-env-8r2kn7u7\overlay\Lib\site-packages\setuptools\dist.py", line 989, in run_command
#           super().run_command(command)
#         File "C:\Users\prana\AppData\Local\Temp\pip-build-env-8r2kn7u7\overlay\Lib\site-packages\setuptools\_distutils\dist.py", line 988, in run_command
#           cmd_obj.run()
#         File "C:\Users\prana\AppData\Local\Temp\pip-build-env-8r2kn7u7\overlay\Lib\site-packages\setuptools\_distutils\command\build.py", line 131, in run
#           self.run_command(cmd_name)
#         File "C:\Users\prana\AppData\Local\Temp\pip-build-env-8r2kn7u7\overlay\Lib\site-packages\setuptools\_distutils\cmd.py", line 318, in run_command
#           self.distribution.run_command(command)
#         File "C:\Users\prana\AppData\Local\Temp\pip-build-env-8r2kn7u7\overlay\Lib\site-packages\setuptools\dist.py", line 989, in run_command
#           super().run_command(command)
#         File "C:\Users\prana\AppData\Local\Temp\pip-build-env-8r2kn7u7\overlay\Lib\site-packages\setuptools\_distutils\dist.py", line 988, in run_command
#           cmd_obj.run()
#         File "<string>", line 130, in run
#         File "<string>", line 167, in build_extension
#         File "C:\ProgramData\anaconda3\Lib\subprocess.py", line 413, in check_call
#           raise CalledProcessError(retcode, cmd)
#       subprocess.CalledProcessError: Command '['cmake', 'C:\\Users\\prana\\AppData\\Local\\Temp\\pip-install-sk3cw1p3\\dlib_d8a741a5b1e3490e9d9384741424ebf3\\tools\\python', '-DCMAKE_LIBRARY_OUTPUT_DIRECTORY=C:\\Users\\prana\\AppData\\Local\\Temp\\pip-install-sk3cw1p3\\dlib_d8a741a5b1e3490e9d9384741424ebf3\\build\\lib.win-amd64-cpython-311', '-DPYTHON_EXECUTABLE=C:\\ProgramData\\anaconda3\\python.exe', '-DCMAKE_LIBRARY_OUTPUT_DIRECTORY_RELEASE=C:\\Users\\prana\\AppData\\Local\\Temp\\pip-install-sk3cw1p3\\dlib_d8a741a5b1e3490e9d9384741424ebf3\\build\\lib.win-amd64-cpython-311', '-A', 'x64']' returned non-zero exit status 1.
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for dlib
# ERROR: Could not build wheels for dlib, which is required to install pyproject.toml-based projects

# %%
! pip install boost
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting boost
#   Downloading boost-0.1.tar.gz (6.3 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting Mastodon.py (from boost)
#   Downloading Mastodon.py-1.8.1-py2.py3-none-any.whl (65 kB)
#      ---------------------------------------- 0.0/65.9 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/65.9 kB ? eta -:--:--
#      ----------------------- -------------- 41.0/65.9 kB 393.8 kB/s eta 0:00:01
#      -------------------------------------- 65.9/65.9 kB 445.6 kB/s eta 0:00:00
# Requirement already satisfied: sqlalchemy in c:\programdata\anaconda3\lib\site-packages (from boost) (1.4.39)
# Requirement already satisfied: requests>=2.4.2 in c:\programdata\anaconda3\lib\site-packages (from Mastodon.py->boost) (2.31.0)
# Requirement already satisfied: python-dateutil in c:\users\prana\appdata\roaming\python\python311\site-packages (from Mastodon.py->boost) (2.8.2)
# Requirement already satisfied: six in c:\users\prana\appdata\roaming\python\python311\site-packages (from Mastodon.py->boost) (1.16.0)
# Requirement already satisfied: decorator>=4.0.0 in c:\users\prana\appdata\roaming\python\python311\site-packages (from Mastodon.py->boost) (5.1.1)
# Collecting blurhash>=1.1.4 (from Mastodon.py->boost)
#   Downloading blurhash-1.1.4-py2.py3-none-any.whl (5.3 kB)
# Collecting python-magic-bin (from Mastodon.py->boost)
#   Downloading python_magic_bin-0.4.14-py2.py3-none-win_amd64.whl (409 kB)
#      ---------------------------------------- 0.0/409.3 kB ? eta -:--:--
#      -------------------------------------  399.4/409.3 kB 8.5 MB/s eta 0:00:01
#      -------------------------------------- 409.3/409.3 kB 6.4 MB/s eta 0:00:00
# Requirement already satisfied: greenlet!=0.4.17 in c:\programdata\anaconda3\lib\site-packages (from sqlalchemy->boost) (2.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.4.2->Mastodon.py->boost) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.4.2->Mastodon.py->boost) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.4.2->Mastodon.py->boost) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.4.2->Mastodon.py->boost) (2023.7.22)
# Building wheels for collected packages: boost
#   Building wheel for boost (setup.py): started
#   Building wheel for boost (setup.py): finished with status 'done'
#   Created wheel for boost: filename=boost-0.1-py3-none-any.whl size=12475 sha256=8fc6a98da3cc65b82d53fd772fa2c5b0fbc20d36251ef43aa8aac90f575a4046
#   Stored in directory: c:\users\prana\appdata\local\pip\cache\wheels\f8\a6\75\884640491fd863d538f82dc27445373b75c3effbee21331891
# Successfully built boost
# Installing collected packages: python-magic-bin, blurhash, Mastodon.py, boost
# Successfully installed Mastodon.py-1.8.1 blurhash-1.1.4 boost-0.1 python-magic-bin-0.4.14

# %%
pip install --upgrade pip
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: pip in c:\users\prana\appdata\roaming\python\python311\site-packages (23.3.1)

# %%
# !pip install dlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting dlib
#   Downloading dlib-19.24.2.tar.gz (11.8 MB)
#      ---------------------------------------- 0.0/11.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.8 MB ? eta -:--:--
#      --------------------------------------- 0.0/11.8 MB 262.6 kB/s eta 0:00:45
#      --------------------------------------- 0.1/11.8 MB 365.7 kB/s eta 0:00:33
#      --------------------------------------- 0.1/11.8 MB 602.4 kB/s eta 0:00:20
#      - -------------------------------------- 0.5/11.8 MB 2.4 MB/s eta 0:00:05
#      - -------------------------------------- 0.5/11.8 MB 2.4 MB/s eta 0:00:05
#      --- ------------------------------------ 0.9/11.8 MB 3.0 MB/s eta 0:00:04
#      ---- ----------------------------------- 1.3/11.8 MB 3.9 MB/s eta 0:00:03
#      ------ --------------------------------- 1.8/11.8 MB 4.2 MB/s eta 0:00:03
#      ------- -------------------------------- 2.3/11.8 MB 5.1 MB/s eta 0:00:02
#      --------- ------------------------------ 2.8/11.8 MB 5.4 MB/s eta 0:00:02
#      ----------- ---------------------------- 3.4/11.8 MB 6.2 MB/s eta 0:00:02
#      ------------ --------------------------- 3.7/11.8 MB 6.0 MB/s eta 0:00:02
#      -------------- ------------------------- 4.2/11.8 MB 6.5 MB/s eta 0:00:02
#      -------------- ------------------------- 4.4/11.8 MB 6.4 MB/s eta 0:00:02
#      ---------------- ----------------------- 4.9/11.8 MB 6.7 MB/s eta 0:00:02
#      ----------------- ---------------------- 5.2/11.8 MB 6.5 MB/s eta 0:00:02
#      -------------------- ------------------- 5.9/11.8 MB 7.1 MB/s eta 0:00:01
#      --------------------- ------------------ 6.2/11.8 MB 7.1 MB/s eta 0:00:01
#      ----------------------- ---------------- 7.0/11.8 MB 7.4 MB/s eta 0:00:01
#      ------------------------- -------------- 7.5/11.8 MB 7.8 MB/s eta 0:00:01
#      -------------------------- ------------- 7.7/11.8 MB 7.5 MB/s eta 0:00:01
#      --------------------------- ------------ 8.1/11.8 MB 7.6 MB/s eta 0:00:01
#      ---------------------------- ----------- 8.4/11.8 MB 7.5 MB/s eta 0:00:01
#      ----------------------------- ---------- 8.8/11.8 MB 7.6 MB/s eta 0:00:01
#      ------------------------------ --------- 8.9/11.8 MB 7.4 MB/s eta 0:00:01
#      ------------------------------- -------- 9.2/11.8 MB 7.4 MB/s eta 0:00:01
#      ------------------------------- -------- 9.3/11.8 MB 7.4 MB/s eta 0:00:01
#      -------------------------------- ------- 9.6/11.8 MB 7.1 MB/s eta 0:00:01
#      -------------------------------- ------- 9.7/11.8 MB 7.0 MB/s eta 0:00:01
#      ---------------------------------- ----- 10.1/11.8 MB 7.0 MB/s eta 0:00:01
#      ----------------------------------- ---- 10.4/11.8 MB 8.0 MB/s eta 0:00:01
#      ----------------------------------- ---- 10.5/11.8 MB 7.7 MB/s eta 0:00:01
#      ------------------------------------ --- 10.8/11.8 MB 7.9 MB/s eta 0:00:01
#      ------------------------------------ --- 10.8/11.8 MB 7.6 MB/s eta 0:00:01
#      ------------------------------------- -- 11.1/11.8 MB 7.6 MB/s eta 0:00:01
#      ------------------------------------- -- 11.1/11.8 MB 7.6 MB/s eta 0:00:01
#      -------------------------------------- - 11.4/11.8 MB 7.1 MB/s eta 0:00:01
#      ---------------------------------------  11.5/11.8 MB 7.0 MB/s eta 0:00:01
#      ---------------------------------------  11.8/11.8 MB 7.0 MB/s eta 0:00:01
#      ---------------------------------------- 11.8/11.8 MB 6.7 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Building wheels for collected packages: dlib
#   Building wheel for dlib (pyproject.toml): started
#   Building wheel for dlib (pyproject.toml): finished with status 'error'
# Failed to build dlib
#   error: subprocess-exited-with-error
#
#   × Building wheel for dlib (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [78 lines of output]
#       running bdist_wheel
#       running build
#       running build_ext
#       <string>:125: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#       Building extension for Python 3.11.5 | packaged by Anaconda, Inc. | (main, Sep 11 2023, 13:26:23) [MSC v.1916 64 bit (AMD64)]
#       Invoking CMake setup: 'cmake C:\Users\prana\AppData\Local\Temp\pip-install-ghp972tu\dlib_9db2752b08c5475eb4b15e980213e8f4\tools\python -DCMAKE_LIBRARY_OUTPUT_DIRECTORY=C:\Users\prana\AppData\Local\Temp\pip-install-ghp972tu\dlib_9db2752b08c5475eb4b15e980213e8f4\build\lib.win-amd64-cpython-311 -DPYTHON_EXECUTABLE=C:\ProgramData\anaconda3\python.exe -DCMAKE_LIBRARY_OUTPUT_DIRECTORY_RELEASE=C:\Users\prana\AppData\Local\Temp\pip-install-ghp972tu\dlib_9db2752b08c5475eb4b15e980213e8f4\build\lib.win-amd64-cpython-311 -A x64'
#       -- Building for: NMake Makefiles
#       CMake Error at CMakeLists.txt:5 (message):
#
#
#
#         !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#
#
#         You must use Visual Studio to build a python extension on windows.  If you
#         are getting this error it means you have not installed Visual C++.  Note
#         that there are many flavors of Visual Studio, like Visual Studio for C#
#         development.  You need to install Visual Studio for C++.
#
#
#         !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#
#
#
#
#       -- Configuring incomplete, errors occurred!
#       Traceback (most recent call last):
#         File "C:\Users\prana\AppData\Roaming\Python\Python311\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 353, in <module>
#           main()
#         File "C:\Users\prana\AppData\Roaming\Python\Python311\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 335, in main
#           json_out['return_val'] = hook(**hook_input['kwargs'])
#                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "C:\Users\prana\AppData\Roaming\Python\Python311\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 251, in build_wheel
#           return _build_backend().build_wheel(wheel_directory, config_settings,
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "C:\Users\prana\AppData\Local\Temp\pip-build-env-0mmtun8z\overlay\Lib\site-packages\setuptools\build_meta.py", line 434, in build_wheel
#           return self._build_with_temp_dir(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "C:\Users\prana\AppData\Local\Temp\pip-build-env-0mmtun8z\overlay\Lib\site-packages\setuptools\build_meta.py", line 419, in _build_with_temp_dir
#           self.run_setup()
#         File "C:\Users\prana\AppData\Local\Temp\pip-build-env-0mmtun8z\overlay\Lib\site-packages\setuptools\build_meta.py", line 341, in run_setup
#           exec(code, locals())
#         File "<string>", line 218, in <module>
#         File "C:\Users\prana\AppData\Local\Temp\pip-build-env-0mmtun8z\overlay\Lib\site-packages\setuptools\__init__.py", line 103, in setup
#           return distutils.core.setup(**attrs)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "C:\Users\prana\AppData\Local\Temp\pip-build-env-0mmtun8z\overlay\Lib\site-packages\setuptools\_distutils\core.py", line 185, in setup
#           return run_commands(dist)
#                  ^^^^^^^^^^^^^^^^^^
#         File "C:\Users\prana\AppData\Local\Temp\pip-build-env-0mmtun8z\overlay\Lib\site-packages\setuptools\_distutils\core.py", line 201, in run_commands
#           dist.run_commands()
#         File "C:\Users\prana\AppData\Local\Temp\pip-build-env-0mmtun8z\overlay\Lib\site-packages\setuptools\_distutils\dist.py", line 969, in run_commands
#           self.run_command(cmd)
#         File "C:\Users\prana\AppData\Local\Temp\pip-build-env-0mmtun8z\overlay\Lib\site-packages\setuptools\dist.py", line 989, in run_command
#           super().run_command(command)
#         File "C:\Users\prana\AppData\Local\Temp\pip-build-env-0mmtun8z\overlay\Lib\site-packages\setuptools\_distutils\dist.py", line 988, in run_command
#           cmd_obj.run()
#         File "C:\Users\prana\AppData\Local\Temp\pip-build-env-0mmtun8z\overlay\Lib\site-packages\wheel\bdist_wheel.py", line 364, in run
#           self.run_command("build")
#         File "C:\Users\prana\AppData\Local\Temp\pip-build-env-0mmtun8z\overlay\Lib\site-packages\setuptools\_distutils\cmd.py", line 318, in run_command
#           self.distribution.run_command(command)
#         File "C:\Users\prana\AppData\Local\Temp\pip-build-env-0mmtun8z\overlay\Lib\site-packages\setuptools\dist.py", line 989, in run_command
#           super().run_command(command)
#         File "C:\Users\prana\AppData\Local\Temp\pip-build-env-0mmtun8z\overlay\Lib\site-packages\setuptools\_distutils\dist.py", line 988, in run_command
#           cmd_obj.run()
#         File "C:\Users\prana\AppData\Local\Temp\pip-build-env-0mmtun8z\overlay\Lib\site-packages\setuptools\_distutils\command\build.py", line 131, in run
#           self.run_command(cmd_name)
#         File "C:\Users\prana\AppData\Local\Temp\pip-build-env-0mmtun8z\overlay\Lib\site-packages\setuptools\_distutils\cmd.py", line 318, in run_command
#           self.distribution.run_command(command)
#         File "C:\Users\prana\AppData\Local\Temp\pip-build-env-0mmtun8z\overlay\Lib\site-packages\setuptools\dist.py", line 989, in run_command
#           super().run_command(command)
#         File "C:\Users\prana\AppData\Local\Temp\pip-build-env-0mmtun8z\overlay\Lib\site-packages\setuptools\_distutils\dist.py", line 988, in run_command
#           cmd_obj.run()
#         File "<string>", line 130, in run
#         File "<string>", line 167, in build_extension
#         File "C:\ProgramData\anaconda3\Lib\subprocess.py", line 413, in check_call
#           raise CalledProcessError(retcode, cmd)
#       subprocess.CalledProcessError: Command '['cmake', 'C:\\Users\\prana\\AppData\\Local\\Temp\\pip-install-ghp972tu\\dlib_9db2752b08c5475eb4b15e980213e8f4\\tools\\python', '-DCMAKE_LIBRARY_OUTPUT_DIRECTORY=C:\\Users\\prana\\AppData\\Local\\Temp\\pip-install-ghp972tu\\dlib_9db2752b08c5475eb4b15e980213e8f4\\build\\lib.win-amd64-cpython-311', '-DPYTHON_EXECUTABLE=C:\\ProgramData\\anaconda3\\python.exe', '-DCMAKE_LIBRARY_OUTPUT_DIRECTORY_RELEASE=C:\\Users\\prana\\AppData\\Local\\Temp\\pip-install-ghp972tu\\dlib_9db2752b08c5475eb4b15e980213e8f4\\build\\lib.win-amd64-cpython-311', '-A', 'x64']' returned non-zero exit status 1.
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for dlib
# ERROR: Could not build wheels for dlib, which is required to install pyproject.toml-based projects

# %%
from scipy.spatial import distance as dist
from imutils.video import VideoStream
from imutils import face_utils
import numpy as np
import imutils
import time
import dlib
import cv2
import matplotlib.pyplot as plt
from keras.preprocessing.image import img_to_array
from keras.models import load_model
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\prana\Downloads\minor project\final.ipynb Cell 9 line 7
#       <a href='vscode-notebook-cell:/c%3A/Users/prana/Downloads/minor%20project/final.ipynb#W4sZmlsZQ%3D%3D?line=4'>5</a> import imutils
#       <a href='vscode-notebook-cell:/c%3A/Users/prana/Downloads/minor%20project/final.ipynb#W4sZmlsZQ%3D%3D?line=5'>6</a> import time
# ----> <a href='vscode-notebook-cell:/c%3A/Users/prana/Downloads/minor%20project/final.ipynb#W4sZmlsZQ%3D%3D?line=6'>7</a> import dlib
#       <a href='vscode-notebook-cell:/c%3A/Users/prana/Downloads/minor%20project/final.ipynb#W4sZmlsZQ%3D%3D?line=7'>8</a> import cv2
#       <a href='vscode-notebook-cell:/c%3A/Users/prana/Downloads/minor%20project/final.ipynb#W4sZmlsZQ%3D%3D?line=8'>9</a> import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'dlib'

# %%
from scipy.spatial import distance as dist
from imutils.video import VideoStream
from imutils import face_utils
import numpy as np
import imutils
import time
import dlib
import cv2
import matplotlib.pyplot as plt
from keras.preprocessing.image import img_to_array
from keras.models import load_model

def eye_brow_distance(leye,reye):
    global points
    distq = dist.euclidean(leye,reye)
    points.append(int(distq))
    return distq

def emotion_finder(faces,frame):
    global emotion_classifier
    EMOTIONS = ["angry" ,"disgust","scared", "happy", "sad", "surprised","neutral"]
    x,y,w,h = face_utils.rect_to_bb(faces)
    frame = frame[y:y+h,x:x+w]
    roi = cv2.resize(frame,(64,64))
    roi = roi.astype("float") / 255.0
    roi = img_to_array(roi)
    roi = np.expand_dims(roi,axis=0)
    preds = emotion_classifier.predict(roi)[0]
    emotion_probability = np.max(preds)
    label = EMOTIONS[preds.argmax()]
    if label in ['scared','sad']:
        label = 'stressed'
    else:
        label = 'not stressed'
    return label
    
def normalize_values(points,disp):
    normalized_value = abs(disp - np.min(points))/abs(np.max(points) - np.min(points))
    stress_value = np.exp(-(normalized_value))
    print(stress_value)
    if stress_value>=75:
        return stress_value,"High Stress"
    else:
        return stress_value,"low_stress"
    
detector = dlib.get_frontal_face_detector()
predictor = dlib.shape_predictor("/Users/saisindhusangavi/Downloads/shape_predictor_68_face_landmarks.dat")
emotion_classifier = load_model("/Users/saisindhusangavi/Downloads/_mini_XCEPTION.102-0.66.hdf5", compile=False)
cap = cv2.VideoCapture(0)
points = []
while(True):
    _,frame = cap.read()
    frame = cv2.flip(frame,1)
    frame = imutils.resize(frame, width=500,height=500)
    
    
    (lBegin, lEnd) = face_utils.FACIAL_LANDMARKS_IDXS["right_eyebrow"]
    (rBegin, rEnd) = face_utils.FACIAL_LANDMARKS_IDXS["left_eyebrow"]

    #preprocessing the image
    gray = cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
    
    detections = detector(gray,0)
    for detection in detections:
        emotion = emotion_finder(detection,gray)
        cv2.putText(frame, emotion, (10,10),cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)
        shape = predictor(frame,detection)
        shape = face_utils.shape_to_np(shape)
           
        leyebrow = shape[lBegin:lEnd]
        reyebrow = shape[rBegin:rEnd]
            
        reyebrowhull = cv2.convexHull(reyebrow)
        leyebrowhull = cv2.convexHull(leyebrow)

        cv2.drawContours(frame, [reyebrowhull], -1, (0, 255, 0), 1)
        cv2.drawContours(frame, [leyebrowhull], -1, (0, 255, 0), 1)

        distq = eye_brow_distance(leyebrow[-1],reyebrow[0])
        stress_value,stress_label = normalize_values(points,distq)
        cv2.putText(frame,"stress level:{}".format(str(int(stress_value*100))),(20,40),cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

    cv2.imshow("Frame", frame)

    key = cv2.waitKey(1) & 0xFF
    if key == ord('q'):
        break
cv2.destroyAllWindows()
cap.release()
plt.plot(range(len(points)),points,'ro')
plt.title("Stress Levels")
plt.show()
# Out:
# 1/1 [==============================] - 0s 177ms/step
# 0.0
# 1/1 [==============================] - 0s 8ms/step
# 0.9854142351016199
# 1/1 [==============================] - 0s 7ms/step
# 0.5738512066460173
# /var/folders/n1/mww7gv896ws8hthvjr8_m0lc0000gn/T/ipykernel_3730/1870758419.py:38: RuntimeWarning: divide by zero encountered in double_scalars
#   normalized_value = abs(disp - np.min(points))/abs(np.max(points) - np.min(points))
# 1/1 [==============================] - 0s 8ms/step
# 0.5738512066460173
# 1/1 [==============================] - 0s 7ms/step
# 0.9430637603061928
# 1/1 [==============================] - 0s 7ms/step
# 0.598171253667083
# 1/1 [==============================] - 0s 7ms/step
# 1.0
# 1/1 [==============================] - 0s 8ms/step
# 0.598171253667083
# 1/1 [==============================] - 0s 7ms/step
# 0.598171253667083
# 1/1 [==============================] - 0s 8ms/step
# 0.6065306597126334
# 1/1 [==============================] - 0s 7ms/step
# 0.598171253667083
# 1/1 [==============================] - 0s 7ms/step
# 0.598171253667083
# 1/1 [==============================] - 0s 7ms/step
# 0.6065306597126334
# 1/1 [==============================] - 0s 7ms/step
# 0.36307393229531576
# 1/1 [==============================] - 0s 7ms/step
# 0.36307393229531576
# 1/1 [==============================] - 0s 7ms/step
# 0.36307393229531576
# 1/1 [==============================] - 0s 7ms/step
# 0.36307393229531576
# 1/1 [==============================] - 0s 7ms/step
# 0.5738512066460173
# 1/1 [==============================] - 0s 7ms/step
# 0.598171253667083
# 1/1 [==============================] - 0s 7ms/step
# 0.36307393229531576
# 1/1 [==============================] - 0s 7ms/step
# 0.598171253667083
# 1/1 [==============================] - 0s 7ms/step
# 0.35584842399944633
# 1/1 [==============================] - 0s 7ms/step
# 0.50893624272641
# 1/1 [==============================] - 0s 7ms/step
# 0.49576278393852113
# 1/1 [==============================] - 0s 7ms/step
# 0.3648284151165656
# 1/1 [==============================] - 0s 7ms/step
# 0.35584842399944633
# 1/1 [==============================] - 0s 7ms/step
# 0.50893624272641
# 1/1 [==============================] - 0s 7ms/step
# 0.7099324466003997
# 1/1 [==============================] - 0s 7ms/step
# 0.7099324466003997
# 1/1 [==============================] - 0s 7ms/step
# 0.35584842399944633
# 1/1 [==============================] - 0s 8ms/step
# 0.7099324466003997
# 1/1 [==============================] - 0s 7ms/step
# 0.7099324466003997
# 1/1 [==============================] - 0s 7ms/step
# 0.3648284151165656
# 1/1 [==============================] - 0s 7ms/step
# 0.35584842399944633
# 1/1 [==============================] - 0s 7ms/step
# 0.7099324466003997
# 1/1 [==============================] - 0s 7ms/step
# 0.7099324466003997
# 1/1 [==============================] - 0s 7ms/step
# 0.7099324466003997
# 1/1 [==============================] - 0s 7ms/step
# 0.6905570013147226
# 1/1 [==============================] - 0s 7ms/step
# 0.7099324466003997
# 1/1 [==============================] - 0s 7ms/step
# 0.50893624272641
# 1/1 [==============================] - 0s 7ms/step
# 0.36787944117144233
# 1/1 [==============================] - 0s 7ms/step
# 0.513417119032592
# 1/1 [==============================] - 0s 7ms/step
# 0.9902523638992113
# 1/1 [==============================] - 0s 7ms/step
# 0.7099324466003997
# 1/1 [==============================] - 0s 7ms/step
# 0.9693506407867475
# 1/1 [==============================] - 0s 7ms/step
# 0.9940728274706588
# 1/1 [==============================] - 0s 7ms/step
# 0.978387479956317
